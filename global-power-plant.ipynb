# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("global-power-plant.csv")

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSIS)

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.shape
# Out:
# (907, 27)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
#checking the column of dataset
df.columns.tolist()
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'capacity_mw',
#  'latitude',
#  'longitude',
#  'primary_fuel',
#  'other_fuel1',
#  'other_fuel2',
#  'other_fuel3',
#  'commissioning_year',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'wepp_id',
#  'year_of_capacity_data',
#  'generation_gwh_2013',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'generation_gwh_2019',
#  'generation_data_source',
#  'estimated_generation_gwh']

# %%
#checking the types of columns
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
df['primary_fuel'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Solar
# 1       Coal
# 2       Wind
# 3        Gas
# 4       Coal
#        ...
# 902     Coal
# 903    Solar
# 904     Wind
# 905     Coal
# 906     Wind
# Name: primary_fuel, Length: 907, dtype: object>

# %% [markdown]
# # checking for missing values

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # VISUALIZATION

# %%
df['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df['primary_fuel'].nunique()
# Out:
# 8

# %%
#checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# IND    907
# Name: country, dtype: int64
#
#
# India    907
# Name: country_long, dtype: int64
#
#
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64
#
#
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# 19.0004    3
# 24.1917    3
# 24.8747    2
# ...

# %%
#checking the uniqe value of quality column
df['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df.shape[0]
# Out:
# 907

# %%
#checking the space in quality column
df.loc[df['primary_fuel']== ' ']
# Out:
# Empty DataFrame
# Columns: [country, country_long, name, gppd_idnr, capacity_mw, latitude, longitude, primary_fuel, other_fuel1, other_fuel2, other_fuel3, commissioning_year, owner, source, url, geolocation_source, wepp_id, year_of_capacity_data, generation_gwh_2013, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018, generation_gwh_2019, generation_data_source, estimated_generation_gwh]
# Index: []
#
# [0 rows x 27 columns]

# %%
df['primary_fuel']=df['primary_fuel'].replace('',np.nan)
df['primary_fuel'].value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
df['capacity_mw']=df['capacity_mw'].astype(float)
df['capacity_mw'].dtype
# Out:
# dtype('float64')

# %%
# Data Analysis and visualization dataset
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   907.000000  861.000000  861.000000          0.0          527.000000
# mean    326.223755   21.197918   77.464907          NaN         1997.091082
# std     590.085456    6.239612    4.939316          NaN           17.082868
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.725000   16.773900   74.256200          NaN         1988.000000
# 50%      59.200000   21.780000   76.719500          NaN         2001.000000
# 75%     385.250000   25.512400   79.440800          NaN         2012.000000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  519.0                  0.0
# mean       NaN                 2019.0                  NaN
# std        NaN                    0.0                  NaN
# ...

# %%
np.mean(df['capacity_mw'])
# Out:
# 326.2237552370453

# %%
df.iloc[488,:]
# Out:
# country                                               IND
# country_long                                        India
# name                                       MUKERIAN I -IV
# gppd_idnr                                      IND0000276
# capacity_mw                                         207.0
# latitude                                          31.9553
# longitude                                          75.836
# primary_fuel                                        Hydro
# other_fuel1                                           NaN
# other_fuel2                                           NaN
# other_fuel3                                           NaN
# commissioning_year                                 1987.0
# owner                                                 NaN
# source                      Central Electricity Authority
# url                                http://www.cea.nic.in/
# geolocation_source                                    WRI
# ...

# %% [markdown]
# # barplot

# %%
#primary vs capacity_mw
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'capacity_mw', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='capacity_mw'>

# %%
#primary_fuel vs generation_gwh_2013
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2013', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2013'>

# %%
#primary_fuel vs generation_gwh_2014
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2014', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2014'>

# %%
#primary_fuel vs generation_gwh_2015
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2015', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2015'>

# %%
#primary_fuel vs generation_gwh_2016
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2016', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2016'>

# %%
#primary_fuel vs generation_gwh_2017
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2017', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2017'>

# %%
#primary_fuel vs generation_gwh_2018
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2018', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2018'>

# %%
#primary_fuel vs generation_gwh_2019
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'generation_gwh_2019', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='generation_gwh_2019'>

# %%
#primary_fuel vs estimated_generation_gwh
plt.figure(figsize=(7,7))
sns.barplot(x='primary_fuel', y= 'estimated_generation_gwh', data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='estimated_generation_gwh'>

# %% [markdown]
# # CORRELATION

# %%
correlation=df.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True, square=True, fmt='.1f' , annot=True, annot_kws={'size':8}, cmap= 'Blues')
# Out:
# <AxesSubplot:>

# %%
x=df.drop('primary_fuel',axis=1)
print(x)
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude other_fuel1 other_fuel2  other_fuel3  \
# 0            2.5   28.1839    73.2407         NaN         NaN          NaN
# ...

# %%
y=df['capacity_mw'].apply(lambda y_value:1 if y_value>=7 else 0 )

# %%
print(y)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 902    1
# 903    0
# 904    1
# 905    1
# 906    1
# Name: capacity_mw, Length: 907, dtype: int64

# %% [markdown]
# # subplot

# %%
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a=df.capacity_mw, kde=False, fit=norm)
# Out:
# <AxesSubplot:xlabel='capacity_mw'>

# %% [markdown]
# # LINEPLOT

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x="country_long", y="primary_fuel", hue='capacity_mw', data=df)
plt.show()

# %% [markdown]
# # checking for skewness

# %%
df.skew()
# Out:
# capacity_mw                 3.123576
# latitude                   -0.145866
# longitude                   1.112646
# other_fuel3                      NaN
# commissioning_year         -1.067949
# wepp_id                          NaN
# year_of_capacity_data       0.000000
# generation_gwh_2013              NaN
# generation_gwh_2014         3.342707
# generation_gwh_2015         3.665904
# generation_gwh_2016         3.512370
# generation_gwh_2017         3.566070
# generation_gwh_2018         3.476298
# generation_gwh_2019              NaN
# estimated_generation_gwh         NaN
# dtype: float64

# %% [markdown]
# # removing skewness

# %%
df['capacity_mw']=np.cbrt(df['capacity_mw'])

# %%
df.skew()
# Out:
# capacity_mw                 1.013378
# latitude                   -0.145866
# longitude                   1.112646
# other_fuel3                      NaN
# commissioning_year         -1.067949
# wepp_id                          NaN
# year_of_capacity_data       0.000000
# generation_gwh_2013              NaN
# generation_gwh_2014         3.342707
# generation_gwh_2015         3.665904
# generation_gwh_2016         3.512370
# generation_gwh_2017         3.566070
# generation_gwh_2018         3.476298
# generation_gwh_2019              NaN
# estimated_generation_gwh         NaN
# dtype: float64

# %% [markdown]
# # ENCODING CATEGORICAL COLUMNS

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=="object":
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      country  country_long   name  gppd_idnr  capacity_mw  latitude  \
# 0        0.0           0.0    0.0      657.0     1.357209   28.1839
# 1        0.0           0.0    1.0      519.0     4.610436   24.7663
# 2        0.0           0.0    2.0      853.0     3.396999   21.9038
# 3        0.0           0.0    3.0        0.0     5.129928   23.8712
# 4        0.0           0.0    4.0        1.0    12.164404   21.9603
# ..       ...           ...    ...        ...          ...       ...
# 902      0.0           0.0  902.0      491.0    11.696071   16.2949
# 903      0.0           0.0  903.0      822.0     1.442250   12.8932
# 904      0.0           0.0  904.0      891.0     2.943383   15.2758
# 905      0.0           0.0  905.0      539.0     4.308869   24.3500
# 906      0.0           0.0  906.0      876.0     2.545822    9.9344
#
#      longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# 0      73.2407           6.0          NaN          NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    float64
#  1   country_long              907 non-null    float64
#  2   name                      907 non-null    float64
#  3   gppd_idnr                 907 non-null    float64
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    float64
#  8   other_fuel1               198 non-null    float64
#  9   other_fuel2               1 non-null      float64
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    float64
# ...

# %%
#statical summary
df.describe()
# Out:
#        country  country_long        name   gppd_idnr  capacity_mw    latitude  \
# count    907.0         907.0  907.000000  907.000000   907.000000  861.000000
# mean       0.0           0.0  453.000000  453.000000     5.044861   21.197918
# std        0.0           0.0  261.972645  261.972645     3.276530    6.239612
# min        0.0           0.0    0.000000    0.000000     0.000000    8.168900
# 25%        0.0           0.0  226.500000  226.500000     2.557290   16.773900
# 50%        0.0           0.0  453.000000  453.000000     3.897390   21.780000
# 75%        0.0           0.0  679.500000  679.500000     7.276319   25.512400
# max        0.0           0.0  906.000000  906.000000    16.821665   34.649000
#
#         longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# count  861.000000    907.000000   198.000000          1.0  ...
# mean    77.464907      3.206174     1.979798          0.0  ...
# std      4.939316      2.280652     0.173340          NaN  ...
# ...

# %% [markdown]
# # correlation between target variable and independent varible

# %%
cor=df.corr()
cor
# Out:
#                           country  country_long      name  gppd_idnr  \
# country                       NaN           NaN       NaN        NaN
# country_long                  NaN           NaN       NaN        NaN
# name                          NaN           NaN  1.000000   0.332205
# gppd_idnr                     NaN           NaN  0.332205   1.000000
# capacity_mw                   NaN           NaN  0.032366  -0.508197
# latitude                      NaN           NaN -0.138764  -0.109151
# longitude                     NaN           NaN  0.020806  -0.390045
# primary_fuel                  NaN           NaN  0.040753   0.609180
# other_fuel1                   NaN           NaN -0.152892  -0.133871
# other_fuel2                   NaN           NaN       NaN        NaN
# other_fuel3                   NaN           NaN       NaN        NaN
# commissioning_year            NaN           NaN -0.057778   0.096678
# owner                         NaN           NaN  0.290702   0.105208
# ...

# %% [markdown]
# # visulazing the correlation matrix by plotting heatmap

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt=".1g",linecolor="black",annot=True,cmap='Blues_r')
plt.yticks(rotation=0);
plt.show()

# %% [markdown]
# # scatterplot

# %%
ax=sns.scatterplot(x="capacity_mw",y="estimated_generation_gwh",data=df)

# %%
ax=sns.scatterplot(x="primary_fuel",y="estimated_generation_gwh",data=df)

# %%
sns.barplot(x=df['primary_fuel'].value_counts().index,y=df['primary_fuel'].value_counts())
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.head()
# Out:
#    country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0      0.0           0.0   0.0      657.0     1.357209   28.1839    73.2407
# 1      0.0           0.0   1.0      519.0     4.610436   24.7663    74.6090
# 2      0.0           0.0   2.0      853.0     3.396999   21.9038    69.3732
# 3      0.0           0.0   3.0        0.0     5.129928   23.8712    91.3602
# 4      0.0           0.0   4.0        1.0    12.164404   21.9603    82.4091
#
#    primary_fuel  other_fuel1  other_fuel2  ...  year_of_capacity_data  \
# 0           6.0          NaN          NaN  ...                    NaN
# 1           1.0          NaN          NaN  ...                    NaN
# 2           7.0          NaN          NaN  ...                    NaN
# 3           2.0          NaN          NaN  ...                 2019.0
# 4           1.0          2.0          NaN  ...                 2019.0
#
#    generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# ...

# %% [markdown]
# # LinearRegression

# %%
df = df.groupby('primary_fuel').mean()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df['capacity_mw']
y = df['country_long']

# %%
reg = LinearRegression()
reg = reg.fit(X.values.reshape(-1,1),y)
predictions = reg.predict(X.values.reshape(-1,1))

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, predictions, color = 'blue')
plt.title('RelationShip between Capasity and expected long')
plt.xlabel('Capasity')
plt.ylabel('Expected long')
plt.show()

# %% [markdown]
# # R2_score

# %%
from sklearn.metrics import r2_score
r2_score(y,predictions)
# Out:
# 1.0

# %%
df=df.sort_values("capacity_mw")

# %%
df['primary_fuel'] = list(df['estimated_generation_gwh'] / df['capacity_mw'])

# %%
df['primary_fuel']=df['primary_fuel'] / df['primary_fuel'].sum() * 1000

# %%
df['the_adjusted_ratio'] = df['primary_fuel'] * df['capacity_mw']

# %%
df
# Out:
#               country  country_long        name   gppd_idnr  capacity_mw  \
# primary_fuel
# 6.0               0.0           0.0  420.362205  756.480315     2.154827
# 0.0               0.0           0.0  416.140000  584.940000     2.675812
# 7.0               0.0           0.0  503.617886  805.300813     2.888660
# 5.0               0.0           0.0  466.650000  409.700000     4.068609
# 3.0               0.0           0.0  459.824701  257.438247     4.623382
# 2.0               0.0           0.0  445.623188  296.637681     6.404004
# 1.0               0.0           0.0  446.899225  350.596899     7.928393
# 4.0               0.0           0.0  437.333333  307.333333     9.298590
#
#                latitude  longitude  other_fuel1  other_fuel2  other_fuel3  \
# primary_fuel
# 6.0           24.095380  74.352328          NaN          NaN          NaN
# 0.0           17.460458  75.679052          NaN          NaN          NaN
# ...

# %%
df.head()
# Out:
#               country  country_long        name   gppd_idnr  capacity_mw  \
# primary_fuel
# 6.0               0.0           0.0  420.362205  756.480315     2.154827
# 0.0               0.0           0.0  416.140000  584.940000     2.675812
# 7.0               0.0           0.0  503.617886  805.300813     2.888660
# 5.0               0.0           0.0  466.650000  409.700000     4.068609
# 3.0               0.0           0.0  459.824701  257.438247     4.623382
#
#                latitude  longitude  other_fuel1  other_fuel2  other_fuel3  \
# primary_fuel
# 6.0           24.095380  74.352328          NaN          NaN          NaN
# 0.0           17.460458  75.679052          NaN          NaN          NaN
# 7.0           17.857224  74.181553          NaN          NaN          NaN
# 5.0           17.311847  74.833806          1.0          NaN          NaN
# 3.0           22.258483  78.846256          NaN          NaN          NaN
#
# ...

# %%
dictionary_of_coefficients = dict(zip(df.index,df['primary_fuel']))

# %%
dictionary_of_coefficients
# Out:
# {6.0: nan,
#  0.0: nan,
#  7.0: nan,
#  5.0: nan,
#  3.0: nan,
#  2.0: nan,
#  1.0: nan,
#  4.0: nan}

# %%
df
# Out:
#               country  country_long        name   gppd_idnr  capacity_mw  \
# primary_fuel
# 6.0               0.0           0.0  420.362205  756.480315     2.154827
# 0.0               0.0           0.0  416.140000  584.940000     2.675812
# 7.0               0.0           0.0  503.617886  805.300813     2.888660
# 5.0               0.0           0.0  466.650000  409.700000     4.068609
# 3.0               0.0           0.0  459.824701  257.438247     4.623382
# 2.0               0.0           0.0  445.623188  296.637681     6.404004
# 1.0               0.0           0.0  446.899225  350.596899     7.928393
# 4.0               0.0           0.0  437.333333  307.333333     9.298590
#
#                latitude  longitude  other_fuel1  other_fuel2  other_fuel3  \
# primary_fuel
# 6.0           24.095380  74.352328          NaN          NaN          NaN
# 0.0           17.460458  75.679052          NaN          NaN          NaN
# ...

# %% [markdown]
# # MODEL BUILDING

# %%
target = df['primary_fuel']
train = df.drop('primary_fuel', axis=1)

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#               country  country_long        name   gppd_idnr  capacity_mw  \
# primary_fuel
# 6.0               0.0           0.0  420.362205  756.480315     2.154827
# 0.0               0.0           0.0  416.140000  584.940000     2.675812
# 7.0               0.0           0.0  503.617886  805.300813     2.888660
# 5.0               0.0           0.0  466.650000  409.700000     4.068609
# 3.0               0.0           0.0  459.824701  257.438247     4.623382
#
#                latitude  longitude  other_fuel1  other_fuel2  other_fuel3  \
# primary_fuel
# 6.0           24.095380  74.352328          NaN          NaN          NaN
# 0.0           17.460458  75.679052          NaN          NaN          NaN
# 7.0           17.857224  74.181553          NaN          NaN          NaN
# 5.0           17.311847  74.833806          1.0          NaN          NaN
# 3.0           22.258483  78.846256          NaN          NaN          NaN
#
# ...

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(train, target, test_size=0.2,random_state=12)

# %%
print(X)
# Out:
# primary_fuel
# 0.0    2.675812
# 1.0    7.928393
# 2.0    6.404004
# 3.0    4.623382
# 4.0    9.298590
# 5.0    4.068609
# 6.0    2.154827
# 7.0    2.888660
# Name: capacity_mw, dtype: float64

# %%
print(y)
# Out:
# primary_fuel
# 0.0    0.0
# 1.0    0.0
# 2.0    0.0
# 3.0    0.0
# 4.0    0.0
# 5.0    0.0
# 6.0    0.0
# 7.0    0.0
# Name: country_long, dtype: float64
